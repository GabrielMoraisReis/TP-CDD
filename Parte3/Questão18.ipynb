# %% [markdown]
# # **Pergunta 18**
#
# **Para respondermos essa pergunta, acreditamos que exibir os dados juntamente com um gráfico de barras para visualização seja interessante.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cine_column = ["CO_CINE_ROTULO", "NO_CINE_AREA_ESPECIFICA"]
cine = pd.read_csv("/content/drive/MyDrive/microdados_educacao_superior_2019/Microdados_Educação_Superior_2019/dados/TB_AUX_CINE_BRASIL_2019.CSV", index_col=False, header=0, encoding="cp860", sep ='|')

# %%
alumn_column = ["ID_ALUNO", "IN_DEFICIENCIA", "CO_CINE_ROTULO"]
Talunos = pd.read_csv(r"/content/drive/MyDrive/Curated/Aluno.csv", index_col=False, header=0, usecols=alumn_column)

# %%
valid_situation = [1]
alunos = Talunos[Talunos['IN_DEFICIENCIA'].isin(valid_situation)]
# Isso busca apenas os alunos que possuem algum tipo de deficiência.

# %% [markdown]
# **Aqui temos as subareas e o número de alunos com deficiência que essa subarea possuem, e também o gráfico de barras mostrando esses dados.**

# %%
cine["CO_CINE_ROTULO"] = cine.CO_CINE_ROTULO.astype(str)
alunos["CO_CINE_ROTULO"] = alunos.CO_CINE_ROTULO.astype(str) 

result = alunos.merge(cine, on="CO_CINE_ROTULO", how='left')
# Merge em tabelas para adicionar a coluna NO_CINE_AREA_ESPECIFICA, que nos dará a informação das subareas.
result['NO_CINE_AREA_ESPECIFICA'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Educaτπo                                                                                              10961
# Neg≤cios e administraτπo                                                                              10692
# Sa·de                                                                                                  7135
# Direito                                                                                                5307
# Computaτπo e Tecnologias da Informaτπo e Comunicaτπo (TIC)                                             3164
# CiΩncias sociais e comportamentais                                                                     2874
# Engenharia e profiss⌡es correlatas                                                                     2740
# Arquitetura e construτπo                                                                               2273
# Bem-estar                                                                                               997
# Produτπo e processamento                                                                                938
# Artes                                                                                                   909
# Serviτos pessoais                                                                                       781
# Agricultura                                                                                             754
# Veterinßria                                                                                             676
# Comunicaτπo e informaτπo                                                                                621
# Humanidades (exceto lφnguas)                                                                            284
# Programas interdisciplinares abrangendo ciΩncias naturais, matemßtica e estatφstica                     282
# CiΩncias biol≤gicas e correlatas                                                                        269
# Programas bßsicos                                                                                       202
# CiΩncias fφsicas                                                                                        188
# Serviτos de seguranτa                                                                                   147
# Lφnguas                                                                                                 114
# Higiene e serviτos de sa·de ocupacional                                                                 104
# Programas interdisciplinares abrangendo ciΩncias sociais, comunicaτπo e informaτπo                      100
# Matemßtica e estatφstica                                                                                 90
# Silvicultura                                                                                             69
# Programas interdisciplinares abrangendo computaτπo e Tecnologias da Informaτπo e Comunicaτπo (TIC)       61
# Programas interdisciplinares abrangendo artes e humanidades                                              56
# Pesca                                                                                                    40
# Programas interdisciplinares abrangendo sa·de e bem-estar                                                33
# Programas interdisciplinares abrangendo educaτπo                                                         29
# Meio ambiente                                                                                            17
# Serviτos de transporte                                                                                   12
# Programas interdisciplinares abrangendo agricultura, silvicultura, pesca e veterinßria                    4
# Programas interdisciplinares abrangendo neg≤cios, administraτπo e direito                                 1
# Name: NO_CINE_AREA_ESPECIFICA, dtype: int64

# %%
sns.countplot(x='NO_CINE_AREA_ESPECIFICA', data=result)
plt.xticks(rotation=90)
plt.xlabel("Subareas")
plt.ylabel("Alunos portadores de deficiências")
plt.show()
